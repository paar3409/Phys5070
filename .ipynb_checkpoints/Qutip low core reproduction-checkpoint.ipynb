# %% [markdown]
# ## This notebook is a compilation of what is needed to reproduce the results from the paper in a basic way.
#
# The main point of this is to have a coherent way to walk someone through the calculations and have them understand what is needed and what is obtained.

# %%
import numpy as np
import qutip as qt
import matplotlib.pyplot as plt
import numpy.testing as npt

# %% [markdown]
# For this simulation we need the hamiltonian and the Lindblad master equation:
#
# ![image.png](attachment:image.png)
#
# $\varepsilon$ is the drive amplitude and $\omega_d$ is the drive frequency on the resonator. $\hbar$ is assumed to be 1. $E_c$ is the transmon charging energy, $E_J$ is the Josephson energy, and n and phi are the charge and phase operators.
# $E_J/E_C=50$, $E_c = 280MHz$, $\omega_t = 7.5GHz$ amd $g/2\pi=250 MHz$. The drive $\varepsilon/2\pi\space\epsilon [0,450] MHz$. Resonator loss rate of $\kappa/2\pi=20 MHz$.
#
# ![image-2.png](attachment:image-2.png)
#
# The dissipator:
# ![image-3.png](attachment:image-3.png)
# Here O and the dot are the lowering operator and density matrix respectively
#
# The system starts in a dressed ground or excited state.

# %%
'''
First we gotta set up the constants for our simulation
'''
E_C = .280 #GHz
E_J = 50*E_C
omega_r = 7.500 #GHz
#omega_r = 2*np.pi*7.500 #GHz
#g = 2*np.pi*.250 #GHz
g = .250 #GHz
kappa = 2*np.pi*0.020 #GHz
#kappa = 0.020 #GHz
omega_d = omega_r
#omega_d = 2*np.pi*omega_r

# %% [markdown]
# The tricky part about simulating this hamiltonian is the fact that we are using two systems so we have to do the hamiltonian in the correct matrix basis and end up adding a lot of dimensionality to it. First I create the hamiltonian for the Transmon only:
#
# ![image.png](attachment:image.png)
#
# and then I must make the one for the readout. Afterwards I must tensor product and add the interaction terms

# %%
'''
Must make the hamiltonian of the system including the interaction terms
'''
def hamiltonian(t, Ec, Ej, N1, N2, omega_r, drive_amp, drive_f, g):
    """
    Return the transmon hamiltonian as a Qobj instance.
    N1 is the qubit order that we are using.
    Ec is the charging energy.
    Ej is the Josephson energy.
    N2 is the readout order that we are using.
    omega_r is the resonator frequency.
    drive_amp is the drive amplitude.
    drive_f is the drive frequency.
    g is the coupling.
    t is time.
    """
    assert N1 != 1
    assert N2 != 1
    
    cos = np.diag(np.ones(N1-1), 1) + np.diag(np.ones(N1-1), -1)
    nt = qt.num(N1)**2 
    transmon = 4 * Ec * ( nt )**2 - 0.5 * Ej * (cos)
                 
    resonator = omega_r*qt.create(N2)*qt.destroy(N2) - 1.j*drive_amp*(qt.destroy(N2)-qt.create(N2))*np.sin(drive_f*t)
    
    interaction = -1.j*g*qt.tensor(qt.num(N1), (qt.destroy(N2)-qt.create(N2)))
    
    Hamilton = qt.tensor(transmon, qt.qeye(N2)) + interaction + qt.tensor(qt.qeye(N1), resonator)
    return Hamilton

# %% [markdown]
# ### Decoherence & Readout
#
# Now gotta setup the decoherence and readout operators

# %%
def resonator_loss(N1,N2):
    return qt.tensor(qt.qeye(N1), qt.destroy(N2))
def number_qubit(N1,N2):
    return qt.tensor(qt.num(N1), qt.qeye(N2))
def number_resonator(N1,N2):
    return qt.tensor(qt.qeye(N1), qt.num(N2))

# %% [markdown]
# ### Initial states
#
# Set up the initial states of the qubit and resonator to explore the desired case.
# The system is initialized in the dressed ground state and in the dressed excited state.

# %%
def ground_state(N1, N2):
    return qt.tensor(qt.basis(N1),qt.basis(N2))
def excited_state(N1, N2):
    return qt.tensor(qt.basis(N1,2),qt.basis(N2))

# %% [markdown]
# ### Qubit dynamics
#
# Setting up the variables of our system.

# %%
times = np.linspace(0, 1/kappa, 51) #0 to kappta*t=1
drives = 2*np.pi*np.linspace(0, 0.450, 11) #GHz

# %% [markdown]
# ### Setting up the actual simulation
# Here I create the actual initial states, relevant operators, ...

# %%
drive1 = 2*np.pi*0.28
N1 = 3 # 32 is what the paper uses
N2 = 20 # 1024 is what the paper uses
nq = number_qubit(N1, N2)
nr = number_resonator(N1, N2)
init_g = ground_state(N1,N2)
init_e = excited_state(N1,N2)
decay = resonator_loss(N1,N2)

A = nq*init_g
np.sum(A[:])
def H(t, idk):
    return hamiltonian(t,E_C, E_J, N1, N2, omega_r, drive1, omega_d, g)

# %% [markdown]
# Solving with the Lindblad Master equation. No guarantee that the below function will converge in a sensible amount of time!
#
# Using the 32 and 1024 dimensions that the paper uses is a guarantee for using a ridiculous amount of memory.

# %%
result_init_g = qt.mesolve(H, init_g, times, [kappa*decay],[nq,nr],args = {})
result_init_g
# Out:
# Result object with mesolve data.
# --------------------------------
# expect = True
# num_expect = 2, num_collapse = 1

# %%
plt.plot(times, result_init_g.expect[0], color = 'black')
plt.plot(times, result_init_g.expect[1], color = 'r')

# %%
result_init_e = qt.mesolve(H, init_e, times, [kappa*decay],[nq,nr],args = {})
result_init_e
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-a2b21e7e7229> in <module>
# ----> 1 result_init_e = qt.mesolve(H, init_e, times, [kappa*decay],[nq,nr],args = {})
#       2 result_init_e
#
# ~\anaconda3\lib\site-packages\qutip\mesolve.py in mesolve(H, rho0, tlist, c_ops, e_ops, args, options, progress_bar, _safe_mode)
#     242         func(0., v, *ode_args) + v
#     243
# --> 244     res = _generic_ode_solve(func, ode_args, rho0, tlist, e_ops, options,
#     245                              progress_bar, dims=rho0.dims)
#     246     res.num_collapse = len(c_ops)
#
# ~\anaconda3\lib\site-packages\qutip\mesolve.py in _generic_ode_solve(func, ode_args, rho0, tlist, e_ops, opt, progress_bar, dims)
#     524
#     525         if t_idx < n_tsteps - 1:
# --> 526             r.integrate(r.t + dt[t_idx])
#     527
#     528     progress_bar.finished()
#
# ~\anaconda3\lib\site-packages\scipy\integrate\_ode.py in integrate(self, t, step, relax)
#     431
#     432         try:
# --> 433             self._y, self.t = mth(self.f, self.jac or (lambda: None),
#     434                                   self._y, self.t, t,
#     435                                   self.f_params, self.jac_params)
#
# ~\anaconda3\lib\site-packages\scipy\integrate\_ode.py in run(self, f, jac, y0, t0, t1, f_params, jac_params)
#    1005         args = ((f, jac, y0, t0, t1) + tuple(self.call_args) +
#    1006                 (f_params, jac_params))
# -> 1007         y1, t, istate = self.runner(*args)
#    1008         self.istate = istate
#    1009         if istate < 0:
#
# ~\anaconda3\lib\site-packages\qutip\mesolve.py in _ode_rho_func_td(t, y, L_func, args)
#     406
#     407 def _ode_rho_func_td(t, y, L_func, args):
# --> 408     L = L_func(t, y, args)
#     409     return spmv(L, y)
#     410
#
# ~\anaconda3\lib\site-packages\qutip\mesolve.py in H2L(self, t, rho, args)
#     335
#     336     def H2L(self, t, rho, args):
# --> 337         Ht = self.f(t, args)
#     338         Lt = -1.0j * (spre(Ht) - spost(Ht))
#     339         _test_liouvillian_dimensions(Lt.dims, self.rho_dims)
#
# <ipython-input-7-92ab4b32e083> in H(t, idk)
#      11 np.sum(A[:])
#      12 def H(t, idk):
# ---> 13     return hamiltonian(t,E_C, E_J, N1, N2, omega_r, drive1, omega_d, g)
#
# <ipython-input-3-6ec762211b6a> in hamiltonian(t, Ec, Ej, N1, N2, omega_r, drive_amp, drive_f, g)
#      24     resonator = omega_r*qt.create(N2)*qt.destroy(N2) - 1.j*drive_amp*(qt.destroy(N2)-qt.create(N2))*np.sin(drive_f*t)
#      25
# ---> 26     interaction = -1.j*g*qt.tensor(qt.num(N1), (qt.destroy(N2)-qt.create(N2)))
#      27
#      28     Hamilton = qt.tensor(transmon, qt.qeye(N2)) + interaction + qt.tensor(qt.qeye(N1), resonator)
#
# ~\anaconda3\lib\site-packages\qutip\qobj.py in __rmul__(self, other)
#     614         elif isinstance(other, numbers.Number):
#     615             out = Qobj()
# --> 616             out.data = other * self.data
#     617             out.dims = self.dims
#     618             out.superrep = self.superrep
#
# ~\anaconda3\lib\site-packages\scipy\sparse\base.py in __rmul__(self, other)
#     541     def __rmul__(self, other):  # other * self
#     542         if isscalarlike(other):
# --> 543             return self.__mul__(other)
#     544         else:
#     545             # Don't use asarray unless we have to
#
# ~\anaconda3\lib\site-packages\scipy\sparse\base.py in __mul__(self, other)
#     473         if isscalarlike(other):
#     474             # scalar value
# --> 475             return self._mul_scalar(other)
#     476
#     477         if issparse(other):
#
# ~\anaconda3\lib\site-packages\scipy\sparse\data.py in _mul_scalar(self, other)
#     122
#     123     def _mul_scalar(self, other):
# --> 124         return self._with_data(self.data * other)
#     125
#     126
#
# ~\anaconda3\lib\site-packages\qutip\fastsparse.py in _with_data(self, data, copy)
#     336         data = np.asarray(data, dtype=complex)
#     337         if copy:
# --> 338             return fast_csr_matrix((data,self.indices.copy(),self.indptr.copy()),
#     339                                    shape=self.shape,dtype=data.dtype)
#     340         else:
#
# KeyboardInterrupt:

# %%
plt.plot(times, result_init_e.expect[0], color = 'black')
plt.plot(times, result_init_e.expect[1], color = 'r')
